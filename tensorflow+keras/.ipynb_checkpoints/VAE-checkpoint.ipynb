# %% [markdown]
# # Autoencoder and Variational Autoencoder
# 本單元，我們將介紹並實作非監督式學習中的自編碼器及其變形

# %% [markdown]
# # 1. 初始準備

# %%
# %env KERAS_BACKEND=tensorflow
# Out:
# env: KERAS_BACKEND=tensorflow

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
from ipywidgets import interact, FloatSlider
from keras.models import Sequential, Model
from keras.layers import Input, Lambda
from keras.layers import Dense  #DNN
from keras.layers import Conv2D, MaxPooling2D  # CNN
from keras.optimizers import SGD, Adam
from keras import metrics

from keras.datasets import mnist

from keras.utils import np_utils
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 2. 讀入MNIST數據庫

# %%
(x_train0, y_train0), (x_test0, y_test0) = mnist.load_data()

# %%
x_train = x_train0.reshape(60000, -1)
x_test = x_test0.reshape(10000, -1)

x_train -= x_train.min()
x_train = x_train/x_train.max()

x_test -= x_test.min()
x_test = x_test/x_test.max()

# %% [markdown]
# # 3. Autoencoder
# ![1558615886756.jpg](attachment:1558615886756.jpg)
# 為了視覺化的目的，經常會考慮 m = 2 的狀況

# %% [markdown]
# # 3.1 Autoencoder 與手寫辨識資料MNIST
# 考慮具有以下結構的 Autoencoder:
# ![1558616350412.jpg](attachment:1558616350412.jpg)

# %%
enc_1 = Dense(100, activation='sigmoid')
enc_2 = Dense(2, activation='sigmoid')

dec_2 = Dense(100, activation='sigmoid')
dec_1 = Dense(784, activation='sigmoid')

# %%
x = Input(shape=(784,))

h = enc_2(enc_1(x))

x_hat = dec_1(dec_2(h))

autoencoder = Model(x, x_hat)
autoencoder .summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               78500
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 202
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               300
# _________________________________________________________________
# dense_4 (Dense)              (None, 784)               79184
# =================================================================
# Total params: 158,186
# Trainable params: 158,186
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 當模型 compile 之後，便可進行資料的訓練、預測

# %%
autoencoder.compile(loss='mse', optimizer=Adam(lr=1e-4))

# %%
autoencoder.fit(x_train, x_train, batch_size=1024, epochs=10)
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.2115
# Epoch 2/10
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.1691
# Epoch 3/10
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.1389
# Epoch 4/10
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.1179
# Epoch 5/10
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1037
# Epoch 6/10
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0940
# Epoch 7/10
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0875
# Epoch 8/10
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0829
# Epoch 9/10
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0796
# Epoch 10/10
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0772

# %% [markdown]
# 使用準備好的權重

# %%
autoencoder.load_weights('autoencoder_handwriting_model_weights.h5')

# %% [markdown]
# # 3.2 視覺化 - 子模型的取出
# 為了視覺化(及其他潛在應用)，我們也會 Autoencoder 將 Encoder 和 Decoder 分別定義出來

# %%
Encoder = Model(x, h)
Encoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               78500
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 78,702
# Trainable params: 78,702
# Non-trainable params: 0
# _________________________________________________________________

# %%
Decoder = Model(h, x_hat) # wrong
# Out:
# D:\anaconda\lib\site-packages\keras\engine\network.py:180: UserWarning: Model inputs must come from `keras.layers.Input` (thus holding past layer metadata), they cannot be the output of a previous non-Input layer. Here, a tensor specified as input to your model was not an Input tensor, it was generated by layer dense_2.
# Note that input tensors are instantiated via `tensor = keras.layers.Input(shape)`.
# The tensor that caused the issue was: dense_2/Sigmoid:0
#   str(x.name))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-9a1b6c1614ed> in <module>
# ----> 1 Decoder = Model(h, x_hat)
#
# D:\anaconda\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# D:\anaconda\lib\site-packages\keras\engine\network.py in __init__(self, *args, **kwargs)
#      91                 'inputs' in kwargs and 'outputs' in kwargs):
#      92             # Graph network
# ---> 93             self._init_graph_network(*args, **kwargs)
#      94         else:
#      95             # Subclassed network
#
# D:\anaconda\lib\site-packages\keras\engine\network.py in _init_graph_network(self, inputs, outputs, name)
#     229         # Keep track of the network's nodes and layers.
#     230         nodes, nodes_by_depth, layers, layers_by_depth = _map_graph_network(
# --> 231             self.inputs, self.outputs)
#     232         self._network_nodes = nodes
#     233         self._nodes_by_depth = nodes_by_depth
#
# D:\anaconda\lib\site-packages\keras\engine\network.py in _map_graph_network(inputs, outputs)
#    1441                                          'The following previous layers '
#    1442                                          'were accessed without issue: ' +
# -> 1443                                          str(layers_with_complete_input))
#    1444                 for x in node.output_tensors:
#    1445                     computable_tensors.append(x)
#
# ValueError: Graph disconnected: cannot obtain value for tensor Tensor("input_1:0", shape=(?, 784), dtype=float32) at layer "input_1". The following previous layers were accessed without issue: []

# %% [markdown]
# Decoder 是由 h 開始，因此我們先準備一個與 h 相同大小的 Input，並餵進 dec_2, dec_1 中

# %%
h_input = Input(shape=(2,))

Decoder = Model(h_input, dec_1(dec_2(h_input)))
Decoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               300
# _________________________________________________________________
# dense_4 (Dense)              (None, 784)               79184
# =================================================================
# Total params: 79,484
# Trainable params: 79,484
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 截至目前為止，我們已經做了甚麼？
# 1. 讀套件
# 2. 讀資料
# 3. 建立並訓練 Autoencoder
# 4. 定義兩個子模型

# %% [markdown]
# # 3.3 視覺化 - Encoder
# 首先，我們隨機抽取一張圖，並透過 Encoder 來算出它的 latent 表示

# %%
idx = 5998
Encoder.predict(x_train[idx:idx+1])
# Out:
# array([[0.2447453 , 0.11025776]], dtype=float32)

# %% [markdown]
# 接著，從 10000 筆測試資料隨機挑選 3000 手寫辨識資料，將其轉換成 latent 表示法，並劃在同一平面上。

# %%
indices = np.random.randint(10000, size=3000)

# %%
latent = Encoder.predict(x_test[indices])
latent.shape
# Out:
# (3000, 2)

# %%
plt.scatter(latent[:, 0], latent[:, 1], c=y_test0[indices], cmap='tab10')
plt.colorbar()

# %% [markdown]
# # 3.4 視覺化 - Decoder
# 首先，我們在 $[0, 1]\times[0, 1]$ 這個單位正方形內均勻取樣 $15*15$ 個點，並將這 $225$ 個平面上的點，透過 Decoder 進行圖片的還原。

# %%
n = 15
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
grid_x = np.linspace(0.05, 0.95, n)
grid_y = np.linspace(0.05, 0.95, n)

# %%
for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = Decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[(n-i-1) * digit_size: (n - i) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

# %%
plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys')
plt.axis('off')
plt.show()

# %% [markdown]
# # 4.Variational Autoencoder
# 若每筆資料的 latent 不僅僅是一個位置，而是一個分布，且分布的平均值附近都能還原，那我們應該怎麼做呢？
#
# 在此，我們將介紹 Variational Autoencder，一種當代知名的自編碼器，就具有上述的效果。
#
# 此時 $\mbox{Enc}$ 和 $\mbox{Dec}$ 並不直接串接，而是會透過一常態抽樣的函數以下面的形式串接。
#
# $$ \mathbb{R}^n \overset{\mbox{Enc}}{\to} \mathbb{R}^m\times\mathbb{R}^m \overset{\mbox{Sampling}}{\to} \mathbb{R}^m \overset{\mbox{Dec}}{\to} \mathbb{R}^n$$$$ x \overset{\mbox{Enc}}{\mapsto} (\mu, \sigma^2) \overset{\mbox{Sampling}}{\mapsto} h \overset{\mbox{Dec}}{\mapsto} \hat{x} $$
# 我們準備建構的 Variational Autoencoder 的結構如下：
#
# ![1558619364799.jpg](attachment:1558619364799.jpg)
#
# 在此， Encoder 的作用不是將資料表示成 latent，而是將資料表示成常態分配的兩個參數，平均數與變異數。
#
# 而 Decoder 也不再直接使用 Encoder 的結果，而是將 Encoder 的結果作為常態抽樣的兩個參數來進行。
#
# 因此，資料經過 Encoder，會得到一適當大小的常態分配之參數，而 Decoder 則使用這組參數進行抽樣。
#
# 即使是同一筆資料，Decoder 每次接受到的 latent 表示法可能都不一樣 (但會在某個平均數附近)。
#
# 要注意到的是，由於變異數恆正的特性，我們可以下面是以學習取對數後的變異數 (log-variance)。

# %% [markdown]
# # 4.1 VAE 的建立
# 為了避免混淆，重新定義所有變數，首先定義 Encoder 上的三個神經網路層

# %%
enc_1 = Dense(100, activation='sigmoid')

enc_mean = Dense(2)
enc_log_var = Dense(2)

dec_2 = Dense(100, activation='sigmoid')
dec_1 = Dense(784, activation='sigmoid')

# %%
x = Input(shape=(784,))

enc_x = enc_1(x)

z_mean = enc_mean(enc_x)
z_log_var = enc_log_var(enc_x)

# %% [markdown]
# 定義抽樣函數並透過 Lambda 將其轉換成 Keras layer。
#
# 透過 $X\sim N(0, 1)\Rightarrow \mu+\sigma X\sim N(\mu, \sigma^2)$ 和 $\sigma = e^{\frac{\log{\sigma^2}}{2}}$，我們透過以下方式定義抽樣函數。

# %%
def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(2,), mean=0, stddev=1)  # X~N(0, 1)
    return z_mean + K.exp(z_log_var / 2) * epsilon

# %%
z = Lambda(sampling, output_shape=(2,))([z_mean, z_log_var])

# %%
x_hat = dec_1(dec_2(z))

# %%
VAE = Model(x, x_hat)
VAE.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 784)          0
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 100)          78500       input_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 2)            202         dense_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 2)            202         dense_5[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 2)            0           dense_6[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 100)          300         lambda_4[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 784)          79184       dense_8[0][0]
# ==================================================================================================
# Total params: 158,388
# Trainable params: 158,388
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # 4.2 Loss 函數的建立
# VAE 的 loss 函數，其由來牽扯一些訊息理論 (information theory) 的知識，因此，我們在此直接建立訓練 VAE 時的 loss 函數。
#
# 若對 VAE 的理論及模型基本設定有興趣的同學，可以參考下列兩篇論文：
#
# Auto-Encoding Variational Bayes: https://arxiv.org/pdf/1312.6114.pdf
# Tutorial on Variational Autoencoders: https://arxiv.org/pdf/1606.05908.pdf
# 同學有興趣可以證明下面關於 KL 散度在兩個常態分配上的性質：若 $p\sim N(\mu_1,\sigma_1^2)$, $q\sim N(\mu_2,\sigma_2^2)$，則 $KL(p, q) = \log\dfrac{\sigma_2}{\sigma_1} + \dfrac{\sigma_1^2+(\mu_1-\mu_2)^2}{2\sigma_2^2}-\dfrac{1}{2}$

# %%
def vae_loss(x, x_recon):
    recovery_loss = 784 * metrics.binary_crossentropy(x, x_recon)
    KL_loss = -0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
    return recovery_loss + KL_loss

# %% [markdown]
# # 4.3 訓練  VAE

# %%
VAE.compile(loss=vae_loss, optimizer=Adam(lr=1e-4))

# %%
VAE.fit(x_train, x_train, batch_size=1024, epochs=10)
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 5s 77us/step - loss: 509.6683
# Epoch 2/10
# 60000/60000 [==============================] - 4s 68us/step - loss: 440.3613
# Epoch 3/10
# 60000/60000 [==============================] - 4s 68us/step - loss: 386.8370
# Epoch 4/10
# 60000/60000 [==============================] - 4s 71us/step - loss: 345.8202
# Epoch 5/10
# 60000/60000 [==============================] - 4s 69us/step - loss: 315.0670
# Epoch 6/10
# 60000/60000 [==============================] - 4s 68us/step - loss: 292.0461
# Epoch 7/10
# 60000/60000 [==============================] - 4s 68us/step - loss: 274.6881
# Epoch 8/10
# 60000/60000 [==============================] - 4s 68us/step - loss: 262.5076
# Epoch 9/10
# 60000/60000 [==============================] - 4s 69us/step - loss: 253.2478
# Epoch 10/10
# 60000/60000 [==============================] - 4s 74us/step - loss: 245.5247

# %%
VAE.load_weights('VAE_handwriting_model_weights.h5')

# %% [markdown]
# # VAE 的視覺化呈現
# 與視覺化 Autoencoder 時的方式一樣，我們先分別定義出 Encoder 和 Decoder。
#
# $$\mbox{VAE:}~x \overset{\mbox{Enc}}{\mapsto} (\mu, \sigma^2) \overset{\mbox{Sampling}}{\mapsto} h \overset{\mbox{Dec}}{\mapsto} \hat{x} $$$$\mbox{Encoder:}~x \overset{\mbox{Enc}}{\mapsto} \mu$$$$\mbox{Decoder:}~h \overset{\mbox{Dec}}{\mapsto} \hat{x}$$

# %%
VAE_encoder = Model(x, z_mean)
VAE_encoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               78500
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 78,702
# Trainable params: 78,702
# Non-trainable params: 0
# _________________________________________________________________

# %%
VAE_decoder = Model(h_input, dec_1(dec_2(h_input)))
VAE_decoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_8 (Dense)              (None, 100)               300
# _________________________________________________________________
# dense_9 (Dense)              (None, 784)               79184
# =================================================================
# Total params: 79,484
# Trainable params: 79,484
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 首先，我們進行 Encoder 的視覺化呈現。

# %%
VAE_latent = VAE_encoder.predict(x_train[indices])
VAE_latent.shape
# Out:
# (3000, 2)

# %%
plt.scatter(VAE_latent[:, 0], VAE_latent[:, 1], c=y_train0[indices], cmap='tab10')
plt.colorbar()

# %%
def normalized(x):
    x -= x.min()
    x /= x.max()
    return x

# %% [markdown]
# 接著，我們進行 Decoder 的視覺化呈現

# %%
grid_x_vae = np.linspace(-4+0.05, 4-0.05, n)
grid_y_vae = np.linspace(-4+0.05, 4-0.05, n)
vae_figure = np.zeros((digit_size*n, digit_size*n))
for i, yi in enumerate(grid_x_vae):
    for j, xi in enumerate(grid_y_vae):
        z_sample = np.array([[xi, yi]])
        x_decoded = VAE_decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        vae_figure[(n-i-1)*digit_size: (n-i)*digit_size, j*digit_size:(j+1)*digit_size] = normalized(digit)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(vae_figure, cmap='Greys')
plt.show()

# %% [markdown]
# # 4.6 動態比較

# %%
def inBetween(t):
    data_0 = x_train0[idx_1]
    data_1 = x_train0[idx_2]
    data_t = (1-t)*x_train0[idx_1] + t*x_train0[idx_2]

    mu_0 = VAE_encoder.predict(x_train[idx_1:idx_1+1]).squeeze()
    mu_1 = VAE_encoder.predict(x_train[idx_2:idx_2+1]).squeeze()
    mu_t = (1-t)*mu_0 + t*mu_1

    plt.figure(figsize=(10, 5))
    ax1 = plt.subplot(2, 1, 2)
    ax1.scatter(mu_0[0], mu_0[1])
    ax1.scatter(mu_1[0], mu_1[1])
    ax1.scatter(mu_t[0], mu_t[1])

    ax2 = plt.subplot(2, 3, 1)
    ax2.imshow(data_0, cmap='Greys')

    ax3 = plt.subplot(2, 3, 2)
    ax3.imshow(data_t, cmap='Greys')

    ax4 = plt.subplot(2, 3, 3)
    ax4.imshow(data_1, cmap='Greys')

# %%
idx_1, idx_2 = np.random.randint(x_test.shape[0], size=2)
data_0 = x_train0[idx_1]
data_1 = x_train0[idx_2]

# %%
interact(inBetween, t=FloatSlider(value=0.5, 
                                  min=0, 
                                  max=1.0,
                                  step=0.02,))
# Out:
# interactive(children=(FloatSlider(value=0.5, description='t', max=1.0, step=0.02), Output()), _dom_classes=('w…
# <function __main__.inBetween(t)>
