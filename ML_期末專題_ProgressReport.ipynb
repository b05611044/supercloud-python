# %% [markdown]
# # 主題：以CNN判斷影片中是否含有色情片段

# %% [markdown]
# ## 組員
# b05611019詹翔宇
# b05611044蔡昀翰
# b05611046薛孟謙

# %% [markdown]
# ## 大綱：
# 1. 介紹 (研究動機)
# 2. 實作方法
# 3. 專案排程
# 4. 目前進度
# 5. 理想目標與嘗試

# %% [markdown]
# ## 研究動機
# 1. 尚未練習過對影片的深度學習實作
# 2. 色情守門員

# %% [markdown]
# ## 研究方法
# 1. 資料來源
# 2. 資料分析
# 3. 資料預處理
# 4. 模型建構

# %% [markdown]
# ### 資料來源
# youtube, pxxnhxb, 18xv, D槽...

# %% [markdown]
# ![messageImage_1558635798709.jpg](attachment:messageImage_1558635798709.jpg)
# ![messageImage_1558637271993.jpg](attachment:messageImage_1558637271993.jpg)

# %% [markdown]
# ### 資料分析

# %% [markdown]
# ![dataset.jpg](attachment:dataset.jpg)

# %% [markdown]
#                                porn: [55, 222, 49, 22, 18, 5, 4], normal: [207, 8, 14, 9, 5, 0, 0]

# %% [markdown]
#                                                                  訓練資料

# %% [markdown]
# ![dataset%28only%20training%29.jpg](attachment:dataset%28only%20training%29.jpg)

# %% [markdown]
#                                 porn: [39, 72, 40, 7, 12, 3, 2], normal: [119, 5, 10, 6, 3, 0, 0]

# %% [markdown]
# ### 資料預處理 + 模型建構

# %% [markdown]
# ![messageImage_1558629614974.jpg](attachment:messageImage_1558629614974.jpg)

# %% [markdown]
# ## 專案排程：
# 第一周： 資料來源 (5/3~5/10)
# 第二周： 資料分析 + 預處理 (5/10~5/17)
# 第三周： 模型建構 + 進度報告 (5/17~5/24)
# 第四周： 模型建構 + 特徵圖 (5/24~5/31)
# 第五周： 期末專題 + 理想目標與嘗試 (5/31~6/7)

# %% [markdown]
# ## 目前進度：
# ![acc.jpg](attachment:acc.jpg)
# ![loss.jpg](attachment:loss.jpg)

# %% [markdown]
# ## 理想目標與嘗試：

# %% [markdown]
# ![CRNN%5B1%5D.png](attachment:CRNN%5B1%5D.png)
