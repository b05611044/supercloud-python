# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-100, 100, 10000)
y = pow(x, 2)
plt.plot(x, y)

# %%
x1 = 75
y1 = x1*x1
plt.plot(x, y)
plt.scatter(x1, y1)
for i in range(20):
    x1 = x1 - 0.1*2*x1
    y1 = x1*x1
    plt.scatter(x1, y1)
