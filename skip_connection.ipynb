# %% [markdown]
# # Outline
# 使用fuction API實作Resnet裡面的skip connection

# %%
# %env KERAS_BACKEND = tensorflow
# Out:
# env: KERAS_BACKEND=tensorflow

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from keras.datasets import mnist
# Out:
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)

# %%
x_train -= x_train.min()
x_train = x_train/x_train.max()
x_test -= x_test.min()
x_test = x_test/x_test.max()

# %%
from keras.utils import np_utils
y_train = np_utils.to_categorical(y_train ,10)
y_test = np_utils.to_categorical(y_test, 10)

# %%
from keras.models import Model
from keras.layers import Input, Activation, Dense, Dropout
from keras.layers import concatenate, add
from keras.callbacks import EarlyStopping, History
from keras.optimizers import SGD

# %% [markdown]
# ![1557687459117.jpg](attachment:1557687459117.jpg)

# %%
f_1 = Dense(1000, activation='relu')
f_2 = Dense(500, activation='relu')
f_3 = Dense(500, activation='sigmoid')
d_1 = Dropout(0.5)
f_4 = Dense(250, activation='relu')
f_5 = Dense(250, activation='sigmoid')
d_2 = Dropout(0.5)
f_6 = Dense(100, activation='relu')
f_7 = Dense(100, activation='relu')
f_8 = Dense(10, activation='softmax')

# %%
x = Input(shape=(784,))
h_1 = f_1(x)
h_2 = f_2(h_1)
h_3 = f_3(h_1)
h_4 = f_4(h_2)
h_5 = f_5(h_2)
con_1 = concatenate([d_1(h_3), h_4, d_2(h_5)])
h_6 = f_6(con_1)
h_7 = f_7(h_1)
y = f_8(add([h_6, h_7]))

# %%
model = Model(x, y)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 784)          0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1000)         785000      input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 500)          500500      dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 500)          500500      dense_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 250)          125250      dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 500)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 250)          125250      dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 250)          0           dense_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1000)         0           dropout_1[0][0]
#                                                                  dense_4[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 100)          100100      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 100)          100100      dense_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 100)          0           dense_6[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 10)           1010        add_1[0][0]
# ==================================================================================================
# Total params: 2,237,710
# Trainable params: 2,237,710
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=SGD(lr=0.01), metrics=['accuracy'])

# %%
skip_connect=model.fit(x_train, y_train, batch_size=100, epochs=20, validation_split=0.1)
# Out:
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/20
# 54000/54000 [==============================] - 26s 482us/step - loss: 0.9419 - acc: 0.7444 - val_loss: 0.3909 - val_acc: 0.9050
# Epoch 2/20
# 54000/54000 [==============================] - 27s 492us/step - loss: 0.4076 - acc: 0.8868 - val_loss: 0.2863 - val_acc: 0.9222
# Epoch 3/20
# 54000/54000 [==============================] - 43s 794us/step - loss: 0.3342 - acc: 0.9049 - val_loss: 0.2520 - val_acc: 0.9308
# Epoch 4/20
# 54000/54000 [==============================] - 43s 804us/step - loss: 0.2986 - acc: 0.9136 - val_loss: 0.2300 - val_acc: 0.9343
# Epoch 5/20
# 54000/54000 [==============================] - 44s 816us/step - loss: 0.2738 - acc: 0.9220 - val_loss: 0.2151 - val_acc: 0.9402
# Epoch 6/20
# 54000/54000 [==============================] - 44s 816us/step - loss: 0.2552 - acc: 0.9271 - val_loss: 0.2024 - val_acc: 0.9447
# Epoch 7/20
# 54000/54000 [==============================] - 45s 828us/step - loss: 0.2390 - acc: 0.9320 - val_loss: 0.1898 - val_acc: 0.9468
# Epoch 8/20
# 54000/54000 [==============================] - 42s 786us/step - loss: 0.2250 - acc: 0.9353 - val_loss: 0.1803 - val_acc: 0.9525
# Epoch 9/20
# 54000/54000 [==============================] - 41s 768us/step - loss: 0.2127 - acc: 0.9393 - val_loss: 0.1733 - val_acc: 0.9555
# Epoch 10/20
# 54000/54000 [==============================] - 43s 793us/step - loss: 0.2014 - acc: 0.9428 - val_loss: 0.1633 - val_acc: 0.9568
# Epoch 11/20
# 54000/54000 [==============================] - 43s 793us/step - loss: 0.1920 - acc: 0.9447 - val_loss: 0.1569 - val_acc: 0.9593
# Epoch 12/20
# 54000/54000 [==============================] - 46s 849us/step - loss: 0.1823 - acc: 0.9482 - val_loss: 0.1507 - val_acc: 0.9620
# Epoch 13/20
# 54000/54000 [==============================] - 44s 822us/step - loss: 0.1737 - acc: 0.9503 - val_loss: 0.1464 - val_acc: 0.9627
# Epoch 14/20
# 54000/54000 [==============================] - 45s 835us/step - loss: 0.1663 - acc: 0.9529 - val_loss: 0.1392 - val_acc: 0.9633
# Epoch 15/20
# 54000/54000 [==============================] - 43s 798us/step - loss: 0.1590 - acc: 0.9549 - val_loss: 0.1342 - val_acc: 0.9648
# Epoch 16/20
# 54000/54000 [==============================] - 42s 787us/step - loss: 0.1526 - acc: 0.9572 - val_loss: 0.1303 - val_acc: 0.9655
# Epoch 17/20
# 54000/54000 [==============================] - 43s 801us/step - loss: 0.1461 - acc: 0.9583 - val_loss: 0.1261 - val_acc: 0.9662
# Epoch 18/20
# 54000/54000 [==============================] - 43s 798us/step - loss: 0.1406 - acc: 0.9607 - val_loss: 0.1232 - val_acc: 0.9672
# Epoch 19/20
# 54000/54000 [==============================] - 43s 796us/step - loss: 0.1352 - acc: 0.9625 - val_loss: 0.1191 - val_acc: 0.9678
# Epoch 20/20
# 54000/54000 [==============================] - 43s 799us/step - loss: 0.1301 - acc: 0.9634 - val_loss: 0.1166 - val_acc: 0.9678

# %%
plt.plot(skip_connect.history['acc'])
plt.plot(skip_connect.history['val_acc'])
plt.title('acc / val_acc')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['acc', 'val_acc'], loc = 'best')
plt.show()

# %%
plt.plot(skip_connect.history['loss'])
plt.plot(skip_connect.history['val_loss'])
plt.title('acc / val_loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc = 'best')
plt.show()
