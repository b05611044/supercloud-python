# %%
# %config IPCompleter.greedy=True 
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import cv2
import urllib.request

# %%
# 下載真實世界中的小女孩照片，並存取成 girl.jpg
urllib.request.urlretrieve('http://www.gx8899.com/uploads/allimg/171025/3-1G025101H3-50.jpg','girl.jpg')
# Out:
# ('girl.jpg', <http.client.HTTPMessage at 0x16a96b904e0>)

# %%
# 對 girl.jpg 進行灰階處理，並秀出來
img1=cv2.imread('girl.jpg')
plt.subplot(1,2,1); plt.imshow(cv2.cvtColor(img1,cv2.COLOR_BGR2RGB))
img1_gray=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)
cv2.imwrite('girl_gray.jpg',img1_gray)
plt.subplot(1,2,2); plt.imshow(img1_gray,cmap='gray');

# %%
# Basic detection using Haar Cascades
urllib.request.urlretrieve('https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml','haarcascade_frontalface_default.xml')
urllib.request.urlretrieve('https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye.xml','haarcascade_eye.xml')
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')
faces = face_cascade.detectMultiScale(img1_gray)
for (x,y,w,h) in faces:
    cv2.rectangle(img1,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = img1_gray[y:y+h, x:x+w]
    roi_color = img1[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
plt.imshow(cv2.cvtColor(img1,cv2.COLOR_BGR2RGB));

# %%
# 下載卡通版的男人照片，並存取成 cartoon_man,jpg
urllib.request.urlretrieve('https://carwad.net/sites/default/files/cartoon-man-face-122093-8970845.jpg','cartoon_man.jpg')
# Out:
# ('cartoon_man.jpg', <http.client.HTTPMessage at 0x16a96afd780>)

# %%
# 對 cartoon_man.jpg 進行灰階處理，並秀出來
img2=cv2.imread('cartoon_man.jpg')
plt.subplot(1,2,1); plt.imshow(cv2.cvtColor(img2,cv2.COLOR_BGR2RGB))
img2_gray=cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
cv2.imwrite('cartoon_man_gray.jpg',img2_gray)
plt.subplot(1,2,2); plt.imshow(img2_gray,cmap='gray');

# %%
# Basic detection using Haar Cascades
urllib.request.urlretrieve('https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml','haarcascade_frontalface_default.xml')
urllib.request.urlretrieve('https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye.xml','haarcascade_eye.xml')
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')
faces = face_cascade.detectMultiScale(img2_gray)
for (x,y,w,h) in faces:
    cv2.rectangle(img2,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = img2_gray[y:y+h, x:x+w]
    roi_color = img2[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
plt.imshow(cv2.cvtColor(img2,cv2.COLOR_BGR2RGB));

# %%
# 下載真實世界中與人臉相似的雲朵照片，並存取成 cloud,jpg
urllib.request.urlretrieve('https://i.imgur.com/zESfT.jpg','cloud.jpg')
# Out:
# ('cloud.jpg', <http.client.HTTPMessage at 0x16a96b40fd0>)

# %%
# 對 cloud.jpg 進行灰階處理，並秀出來
img3=cv2.imread('cloud.jpg')
plt.subplot(1,2,1); plt.imshow(cv2.cvtColor(img3,cv2.COLOR_BGR2RGB))
img3_gray=cv2.cvtColor(img3,cv2.COLOR_BGR2GRAY)
cv2.imwrite('cloud_gray.jpg',img3_gray)
plt.subplot(1,2,2); plt.imshow(img3_gray,cmap='gray');

# %%
# Basic detection using Haar Cascades
import urllib.request
urllib.request.urlretrieve('https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml','haarcascade_frontalface_default.xml')
urllib.request.urlretrieve('https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye.xml','haarcascade_eye.xml')
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')
faces = face_cascade.detectMultiScale(img3_gray)
for (x,y,w,h) in faces:
    cv2.rectangle(img3,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = img3_gray[y:y+h, x:x+w]
    roi_color = img3[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
plt.imshow(cv2.cvtColor(img3,cv2.COLOR_BGR2RGB));

# %%
#從第一張圖片判斷此model有足夠的能力辨識出人臉及人眼
#無法從第二張卡通人物圖片中辨識出人臉，推測原因是因為其不是立體的，沒有輪廓亦沒有陰影
#可以從第三張天空圖片中辨識出人臉，因為它具有足夠充足的輪廓和陰影，但因陰影條件並不是非常理想，所以其中一隻眼睛錯位了
