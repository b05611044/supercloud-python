# %% [markdown]
# # 主題：以CNN判斷影片中是否含有色情片段

# %% [markdown]
# ## 組員
# b05611019詹翔宇
# b05611044蔡昀翰
# b05611046薛孟謙

# %% [markdown]
# ## 大綱：
# 1. 介紹 (研究動機)
# 2. 實作方法
# 3. 專案排程
# 4. 目前進度
# 5. 理想目標與嘗試

# %% [markdown]
# ## 研究動機
# 1. 尚未練習過對影片的深度學習實作
# 2. 色情守門員

# %% [markdown]
# ## 研究方法
# 1. data source
# 2. data analyzing
# 3. data pre-processing
# 4. model architecture

# %% [markdown]
# ### data source
# youtube, pxxnhxb, 18xv, D drive...

# %% [markdown]
# ![dataset.jpg](attachment:dataset.jpg)

# %% [markdown]
#                                porn: [55, 222, 49, 22, 18, 5, 4], normal: [207, 8, 14, 9, 5, 0, 0]

# %% [markdown]
# ### data analyzing

# %% [markdown]
# ![1558593256908.jpg](attachment:1558593256908.jpg)

# %% [markdown]
# ![dataset%28only%20training%29.jpg](attachment:dataset%28only%20training%29.jpg)

# %% [markdown]
#                                 porn: [39, 72, 40, 7, 12, 3, 2], normal: [119, 5, 10, 6, 3, 0, 0]

# %% [markdown]
# ### data pre-processing

# %% [markdown]
# ### model architecture

# %% [markdown]
# ## 專案排程：
# week 1: data source (5/3~5/10)
# week 2: data analyzing + data preprocessing (5/10~5/17)
# week 3: model architecture + progress report (5/17~5/24)
# week 4: model architecture + feature map (5/24~5/31)
# week 5: more attempts + final project (5/31~6/7)

# %% [markdown]
# ## 目前進度：
# ![acc.jpg](attachment:acc.jpg)
# ![loss.jpg](attachment:loss.jpg)

# %% [markdown]
# ## 理想目標與嘗試：
